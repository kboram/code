# %% [markdown]
# 라이브러리 불러오기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 시각화 스타일 설정
sns.set(style='whitegrid')

# %%
# 설치된 모든 라이브러리 버전 확인
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit                : d9cdd2ee5a58015ef6f4d15c7226110c9aab8140
# python                : 3.12.3.final.0
# python-bits           : 64
# OS                    : Windows
# OS-release            : 11
# Version               : 10.0.26100
# machine               : AMD64
# processor             : AMD64 Family 23 Model 96 Stepping 1, AuthenticAMD
# byteorder             : little
# LC_ALL                : None
# LANG                  : None
# LOCALE                : Korean_Korea.949
#
# pandas                : 2.2.2
# numpy                 : 1.26.4
# pytz                  : 2024.1
# dateutil              : 2.9.0.post0
# setuptools            : 75.1.0
# pip                   : 25.0
# Cython                : None
# pytest                : 7.4.4
# hypothesis            : None
# sphinx                : 7.3.7
# blosc                 : None
# feather               : None
# xlsxwriter            : None
# lxml.etree            : 5.2.1
# ...

# %% [markdown]
# 데이터 불러오기

# %%
# 기준금리
interest = pd.read_csv(r"C:\Users\LENOVO\권보람\바탕 화면\빅데이터처리_프로젝트_데이터\기준금리.csv")

# 소비자물가지수(CPI)
cpi = pd.read_csv(r"C:\Users\LENOVO\권보람\바탕 화면\빅데이터처리_프로젝트_데이터\소비자물가지수.csv")

# 생활물가지수
living_cpi = pd.read_csv(r"C:\Users\LENOVO\권보람\바탕 화면\빅데이터처리_프로젝트_데이터\생활물가지수.csv", encoding='cp949')

# 예금은행 대출금리
loan_rate = pd.read_csv(r"C:\Users\LENOVO\권보람\바탕 화면\빅데이터처리_프로젝트_데이터\예금은행 대출금리(신규취급액 기준)_29194950.csv")

# 신용카드 사용액
card_usage = pd.read_csv(r"C:\Users\LENOVO\권보람\바탕 화면\빅데이터처리_프로젝트_데이터\신용카드 사용액.csv")

# 가처분소득
income = pd.read_csv(r"C:\Users\LENOVO\권보람\바탕 화면\빅데이터처리_프로젝트_데이터\가처분소득.csv", encoding='cp949')

# 가계지출 (2006~2016, 2017~2018[연간], 2019~2025)
expend1 = pd.read_csv(r"C:\Users\LENOVO\권보람\바탕 화면\빅데이터처리_프로젝트_데이터\가계지출(2006~2016).csv", encoding='cp949')
expend2 = pd.read_csv(r"C:\Users\LENOVO\권보람\바탕 화면\빅데이터처리_프로젝트_데이터\가계지출(2017~2018).csv", encoding='cp949')
expend3 = pd.read_csv(r"C:\Users\LENOVO\권보람\바탕 화면\빅데이터처리_프로젝트_데이터\가계지출(2019~2025).csv", encoding='cp949')

# 임금총액
wage1 = pd.read_csv(r"C:\Users\LENOVO\권보람\바탕 화면\빅데이터처리_프로젝트_데이터\임금총액 (1).csv", encoding='cp949')
wage2 = pd.read_csv(r"C:\Users\LENOVO\권보람\바탕 화면\빅데이터처리_프로젝트_데이터\임금총액 (2).csv", encoding='cp949')

# %%
# 데이터 데이터프레임 정보 확인
wage1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Columns: 110 entries, 산업분류별(1) to 2019.12
# dtypes: object(110)
# memory usage: 13.0+ KB

# %%
# 데이터 데이터프레임 정보 확인
wage2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 64 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   산업분류(1)  15 non-null     object
#  1   규모별(1)   15 non-null     object
#  2   2020.01  15 non-null     object
#  3   2020.02  15 non-null     object
#  4   2020.03  15 non-null     object
#  5   2020.04  15 non-null     object
#  6   2020.05  15 non-null     object
#  7   2020.06  15 non-null     object
#  8   2020.07  15 non-null     object
#  9   2020.08  15 non-null     object
#  10  2020.09  15 non-null     object
#  11  2020.10  15 non-null     object
#  12  2020.11  15 non-null     object
#  13  2020.12  15 non-null     object
#  14  2021.01  15 non-null     object
#  15  2021.02  15 non-null     object
#  16  2021.03  15 non-null     object
#  17  2021.04  15 non-null     object
#  18  2021.05  15 non-null     object
#  19  2021.06  15 non-null     object
# ...

# %%
# 데이터 데이터프레임 정보 확인
interest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Columns: 309 entries, 통계표 to 2025/04
# dtypes: float64(304), int64(1), object(4)
# memory usage: 2.5+ KB

# %%
# 데이터 데이터프레임 정보 확인
cpi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 581 entries, 0 to 580
# Columns: 310 entries, 통계표 to 2025/04
# dtypes: float64(303), object(7)
# memory usage: 1.4+ MB

# %%
# 데이터 데이터프레임 정보 확인
living_cpi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Columns: 309 entries, 시도별 to Unnamed: 308
# dtypes: float64(305), object(4)
# memory usage: 364.7+ KB

# %%
# 데이터 데이터프레임 정보 확인
loan_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Columns: 309 entries, 통계표 to 2025/04
# dtypes: float64(304), object(5)
# memory usage: 46.0+ KB

# %%
# 데이터 데이터프레임 정보 확인
card_usage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Columns: 273 entries, 통계표 to 2025/02
# dtypes: int64(2), object(271)
# memory usage: 8.7+ KB

# %%
# 데이터 데이터프레임 정보 확인
income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 25 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   계정항목별   4 non-null      object
#  1   2000    4 non-null      float64
#  2   2001    4 non-null      float64
#  3   2002    4 non-null      float64
#  4   2003    4 non-null      float64
#  5   2004    4 non-null      float64
#  6   2005    4 non-null      float64
#  7   2006    4 non-null      float64
#  8   2007    4 non-null      float64
#  9   2008    4 non-null      float64
#  10  2009    4 non-null      float64
#  11  2010    4 non-null      float64
#  12  2011    4 non-null      float64
#  13  2012    4 non-null      float64
#  14  2013    4 non-null      float64
#  15  2014    4 non-null      float64
#  16  2015    4 non-null      float64
#  17  2016    4 non-null      float64
#  18  2017    4 non-null      float64
#  19  2018    4 non-null      float64
#  20  2019    4 non-null      float64
# ...

# %%
# 데이터 데이터프레임 정보 확인
expend1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Columns: 133 entries, 가계수지항목별 to 2016.4/4.2
# dtypes: object(133)
# memory usage: 18.8+ KB

# %%
# 데이터 데이터프레임 정보 확인
expend2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   가계지출항목별  18 non-null     object
#  1   2017     18 non-null     object
#  2   2017.1   18 non-null     object
#  3   2017.2   18 non-null     object
#  4   2018     18 non-null     object
#  5   2018.1   18 non-null     object
#  6   2018.2   18 non-null     object
# dtypes: object(7)
# memory usage: 1.1+ KB

# %%
# 데이터 데이터프레임 정보 확인
expend3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 76 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   가계수지항목별     18 non-null     object
#  1   2019.1/4    18 non-null     object
#  2   2019.1/4.1  18 non-null     object
#  3   2019.1/4.2  18 non-null     object
#  4   2019.2/4    18 non-null     object
#  5   2019.2/4.1  18 non-null     object
#  6   2019.2/4.2  18 non-null     object
#  7   2019.3/4    18 non-null     object
#  8   2019.3/4.1  18 non-null     object
#  9   2019.3/4.2  18 non-null     object
#  10  2019.4/4    18 non-null     object
#  11  2019.4/4.1  18 non-null     object
#  12  2019.4/4.2  18 non-null     object
#  13  2020.1/4    18 non-null     object
#  14  2020.1/4.1  18 non-null     object
#  15  2020.1/4.2  18 non-null     object
#  16  2020.2/4    18 non-null     object
#  17  2020.2/4.1  18 non-null     object
#  18  2020.2/4.2  18 non-null     object
# ...

# %%
# 임금총액 데이터 상위 5개 레코드 확인
wage1.head()
# Out:
#    산업분류별(1)     규모별(1)     2011.01     2011.02     2011.03     2011.04  \
# 0  산업분류별(1)     규모별(1)  전체임금총액 (원)  전체임금총액 (원)  전체임금총액 (원)  전체임금총액 (원)
# 1        전체  전규모(1인이상)     2726580     2550340     2509242     2494914
# 2        전체      -5인이상     2991049     2768429     2732143     2718715
# 3        전체     -10인이상     3173519     2920887     2890081     2871554
# 4        전체     -30인이상     3503632     3204151     3178101     3150886
#
#       2011.05     2011.06     2011.07     2011.08  ...     2019.03  \
# 0  전체임금총액 (원)  전체임금총액 (원)  전체임금총액 (원)  전체임금총액 (원)  ...  전체임금총액 (원)
# 1     2402915     2561934     2654356     2648146  ...     3396664
# 2     2600331     2789656     2898494     2893090  ...     3708483
# 3     2730771     2952306     3084420     3077036  ...     3923561
# 4     2950859     3277238     3416983     3403919  ...     4237938
#
#       2019.04     2019.05     2019.06     2019.07     2019.08     2019.09  \
# ...

# %%
wage2.head()
# Out:
#    산업분류(1)     규모별(1)     2020.01     2020.02     2020.03     2020.04  \
# 0  산업분류(1)     규모별(1)  전체임금총액 (원)  전체임금총액 (원)  전체임금총액 (원)  전체임금총액 (원)
# 1       전체  전규모(1인이상)     4091969     3403361     3473131     3358565
# 2       전체      -5인이상     4515306     3710819     3780473     3647512
# 3       전체     -10인이상     4827529     3918737     3995055     3841393
# 4       전체     -30인이상     5320333     4215557     4283531     4093342
#
#       2020.05     2020.06     2020.07     2020.08  ...     2024.05  \
# 0  전체임금총액 (원)  전체임금총액 (원)  전체임금총액 (원)  전체임금총액 (원)  ...  전체임금총액 (원)
# 1     3287099     3351376     3526470     3378692  ...     3822581
# 2     3561265     3639058     3846353     3668334  ...     4143005
# 3     3739810     3833572     4051563     3865931  ...     4326413
# 4     3954701     4083540     4359192     4133330  ...     4630801
#
#       2024.06     2024.07     2024.08     2024.09     2024.10     2024.11  \
# ...

# %%
# 기준금리 데이터 레코드 확인
interest.head()
# Out:
#                         통계표  코드(계정항목)       계정항목  단위   변환  2000/01  2000/02  \
# 0  1.3.1. 한국은행 기준금리 및 여수신금리    101000  한국은행 기준금리  연%  원자료     4.75      5.0
#
#    2000/03  2000/04  2000/05  ...  2024/07  2024/08  2024/09  2024/10  \
# 0      5.0      5.0      5.0  ...      3.5      3.5      3.5     3.25
#
#    2024/11  2024/12  2025/01  2025/02  2025/03  2025/04
# 0      3.0      3.0      3.0     2.75     2.75     2.75
#
# [1 rows x 309 columns]

# %%
# 소비자물가지수(CPI) 데이터 상위 5개 레코드 확인
cpi.head()
# Out:
#               통계표 코드(계정항목)           계정항목        단위     가중치   변환  2000/01  \
# 0  4.2.1. 소비자물가지수        0            총지수  2020=100  1000.0  원자료   62.456
# 1  4.2.1. 소비자물가지수        A    식료품 및 비주류음료  2020=100   142.0  원자료   48.264
# 2  4.2.1. 소비자물가지수      A01            식료품  2020=100   132.3  원자료   47.924
# 3  4.2.1. 소비자물가지수     A011         빵 및 곡물  2020=100    22.3  원자료   63.679
# 4  4.2.1. 소비자물가지수   A01101              쌀  2020=100     4.2  원자료   73.779
#
#    2000/02  2000/03  2000/04  ...  2024/07  2024/08  2024/09  2024/10  \
# 0   62.647   62.962   62.709  ...   114.13   114.54   114.65   114.69
# 1   48.697   48.457   47.547  ...   121.54   122.99   124.72   124.53
# 2   48.304   48.066   47.117  ...   121.57   123.16   125.05   124.74
# 3   63.874   63.939   63.810  ...   118.53   118.27   117.88   119.01
# 4   73.928   74.003   73.928  ...   100.35    98.78    98.35    99.18
#
#    2024/11  2024/12  2025/01 2025/02 2025/03  2025/04
# ...

# %%
# 생활물가지수 데이터 상위 5개 레코드 확인
living_cpi.head()
# Out:
#   시도별     품목별                항목        단위  2000.01 월  2000.02 월  2000.03 월  \
# 0  전국     총지수  생활물가지수[2020=100]  2020=100     62.456     62.647     62.962
# 1  전국  생활물가지수  생활물가지수[2020=100]  2020=100     59.934     60.237     60.787
# 2  전국      식품  생활물가지수[2020=100]  2020=100        NaN        NaN        NaN
# 3  전국       쌀  생활물가지수[2020=100]  2020=100     73.779     73.928     74.003
# 4  전국      국수  생활물가지수[2020=100]  2020=100        NaN        NaN        NaN
#
#    2000.04 월  2000.05 월  2000.06 월  ...  2024.08 월  2024.09 월  2024.10 월  \
# 0     62.709     62.393     62.709  ...     114.54     114.65     114.69
# 1     60.422     59.751     60.177  ...     116.96     117.45     117.51
# 2        NaN        NaN        NaN  ...     123.00     124.06     124.35
# 3     73.928     74.378     74.904  ...      98.78      98.35      99.18
# 4        NaN        NaN        NaN  ...     150.80     150.40     153.69
#
#    2024.11 월  2024.12 월  2025.01 월  2025.02 월  2025.03 월  2025.04 월  \
# ...

# %%
# 예금은행 대출금리 데이터 상위 5개 레코드 확인
loan_rate.head()
# Out:
#                               통계표    코드(계정항목)          계정항목   단위   변환  \
# 0  1.3.3.2.1. 예금은행 대출금리(신규취급액 기준)    BECBLA01       대출평균 1)   연%  원자료
# 1  1.3.3.2.1. 예금은행 대출금리(신규취급액 기준)    BECBLA02          기업대출  연리%  원자료
# 2  1.3.3.2.1. 예금은행 대출금리(신규취급액 기준)  BECBLA0201         대기업대출  연리%  원자료
# 3  1.3.3.2.1. 예금은행 대출금리(신규취급액 기준)  BECBLA0202        중소기업대출  연리%  원자료
# 4  1.3.3.2.1. 예금은행 대출금리(신규취급액 기준)  BECBLA0203        운전자금대출  연리%  원자료
#
#    2000/01  2000/02  2000/03  2000/04  2000/05  ...  2024/07  2024/08  \
# 0     8.59     8.64     8.79     8.61     8.62  ...     4.55     4.48
# 1     8.22     8.24     8.44     8.20     8.24  ...     4.78     4.67
# 2     8.96     8.58     9.15     8.62     8.83  ...     4.89     4.78
# 3     7.99     8.14     8.16     8.03     8.01  ...     4.69     4.59
# 4     8.18     8.21     8.37     8.18     8.20  ...     4.99     4.90
#
#    2024/09  2024/10  2024/11  2024/12  2025/01  2025/02  2025/03  2025/04
# ...

# %%
# 신용카드 사용액 데이터 상위 5개 레코드 확인
card_usage.head()
# Out:
#            통계표  코드(계정항목)               계정항목  코드(금융기관 유형코드) 금융기관 유형코드   단위  \
# 0  7.5.1. 신용카드    201000            개인 이용금액              0        합계  백만원
# 1  7.5.1. 신용카드    201010       개인 일반구매 이용금액              0        합계  백만원
# 2  7.5.1. 신용카드    201020       개인 할부구매 이용금액              0        합계  백만원
# 3  7.5.1. 신용카드    201030      개인 현금서비스 이용금액              0        합계  백만원
#
#     변환      2003/01      2003/02      2003/03  ...      2024/05      2024/06  \
# 0  원자료  39,003,059   36,557,544   37,973,043   ...  71,470,287   69,465,828
# 1  원자료   7,515,726    7,048,190    7,620,740   ...  53,499,092   52,135,546
# 2  원자료   5,347,723    4,631,175    5,009,576   ...  13,083,041   12,624,201
# 3  원자료  26,139,610   24,878,179   25,342,727   ...   4,888,154    4,706,080
#
#        2024/07      2024/08      2024/09      2024/10      2024/11  \
# 0  72,481,951   71,014,563   70,148,013   73,065,817   71,922,129
# 1  53,659,153   53,355,590   52,491,264   53,883,973   53,147,187
# ...

# %%
# 가처분소득 데이터 상위 5개 레코드 확인
income.head()
# Out:
#           계정항목별      2000      2001      2002      2003      2004      2005  \
# 0      국민처분가능소득  558308.7  601954.7  674575.0  716733.7  780783.0  817883.6
# 1  c.법인(금융기관포함)   40339.9   46488.8   71235.4   70205.3   90778.0   82328.0
# 2        c.일반정부  129340.9  138424.2  153462.6  166295.4  168984.6  190142.7
# 3  c.가계 및 비영리단체  388627.9  417041.7  449877.0  480233.0  521020.5  545412.8
#
#        2006      2007      2008  ...       2014       2015       2016  \
# 0  861429.1  940342.5  988597.9  ...  1332691.0  1416721.8  1494841.8
# 1   81537.3   96837.3   96676.2  ...   156975.7   163696.3   185261.9
# 2  208004.4  234395.1  233308.4  ...   298289.6   315273.4   345959.4
# 3  571887.3  609110.2  658613.3  ...   877425.8   937752.2   963620.6
#
#         2017       2018       2019       2020       2021       2022       2023
# 0  1577031.4  1628018.5  1648030.4  1648918.5  1780892.1  1840003.0  1894840.8
# ...

# %%
expend1.head()
# Out:
#      가계수지항목별 2006.1/4 2006.1/4.1 2006.1/4.2 2006.2/4 2006.2/4.1 2006.2/4.2  \
# 0    가계수지항목별     전체가구      근로자가구     근로자외가구     전체가구      근로자가구     근로자외가구
# 1   가구원수 (명)     2.99       3.14       2.81     2.93       3.08       2.73
# 2  가구주연령 (세)    47.72      43.52      52.95    48.02      43.93      53.38
# 3   가계지출 (원)  3043523    3360532    2648870  2824036    3081559    2486900
# 4   소비지출 (원)  2417299    2615980    2169955  2205315    2358240    2005113
#
#   2006.3/4 2006.3/4.1 2006.3/4.2  ... 2016.1/4.2 2016.2/4 2016.2/4.1  \
# 0     전체가구      근로자가구     근로자외가구  ...     근로자외가구     전체가구      근로자가구
# 1     2.92       3.07       2.72  ...       2.26     2.59       2.82
# 2    48.27      43.92       53.8  ...      59.65    52.97      48.42
# 3  2877900    3178906    2495030  ...    2414324  2924525    3376302
# 4  2255332    2445122    2013923  ...    1913750  2220647    2494859
#
#   2016.2/4.2 2016.3/4 2016.3/4.1 2016.3/4.2 2016.4/4 2016.4/4.1 2016.4/4.2
# ...

# %% [raw]
# expend2.head()

# %%
expend3.head()
# Out:
#    가계수지항목별 2019.1/4 2019.1/4.1 2019.1/4.2 2019.2/4 2019.2/4.1 2019.2/4.2  \
# 0  가계수지항목별     전체가구      근로자가구     근로자외가구     전체가구      근로자가구     근로자외가구
# 1     가구원수     2.42       2.61       2.18     2.41       2.56       2.19
# 2    가구주연령     52.2      46.71      59.57    52.15       47.6       58.9
# 3     가계지출  3489987    4063951    2720331  3206094    3670565    2517365
# 4     소비지출  2567902    2902648    2119024  2367963    2627497    1983119
#
#   2019.3/4 2019.3/4.1 2019.3/4.2  ... 2024.2/4.2 2024.3/4 2024.3/4.1  \
# 0     전체가구      근로자가구     근로자외가구  ...     근로자외가구     전체가구      근로자가구
# 1     2.42       2.56       2.22  ...       2.11     2.25       2.35
# 2    52.03      47.17      58.99  ...      59.61    53.04      48.65
# 3  3404750    3890609    2709286  ...    2651649  3473574    3933658
# 4  2480951    2765597    2073506  ...    2114021  2540587    2791865
#
#   2024.3/4.2 2024.4/4 2024.4/4.1 2024.4/4.2 2025.1/4 2025.1/4.1 2025.1/4.2
# ...

# %% [raw]
# 가계지출 데이터 연도별로 변환
